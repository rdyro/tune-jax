# %%
from functools import partial
from pprint import pprint

import jax
import jax.numpy as jnp

import tune_jax

# %%
# !uv pip install -U --force-reinstall -q tune-jax
# or
# !uv pip install -U git+https://github.com/rdyro/tune-jax.git

# %%
@partial(jax.jit, static_argnames=("steps",))
def fn(x, W, steps=20):
  for i in range(steps):
    x = (x @ W) / jnp.linalg.norm(x, axis=-1, keepdims=True)
  return x

# %% [markdown]
# ### Just timing the function

# %%
x = jnp.ones((128, 1024))
W = jnp.ones((1024, 1024))

fn_tune = tune_jax.tune(fn)
fn_tune(x, W)
fn_tune.timing_results
# Out:
# {0: TimingResult(hyperparams={}, t_mean=3.7385333333333336e-05, t_std=2.3795424396767122e-08)}

# %%
fn_tune(x, W).shape  # no retuning on no shape change
# Out:
# (128, 1024)

# %% [markdown]
# ### Tuning

# %%
x = jnp.ones((16, 1024))
W = jnp.ones((1024, 1024))

hyperparams = {"steps": [1, 2, 3, 30, 50]}
fn_tune = tune_jax.tune(fn, hyperparams=hyperparams)
fn_tune(x, W)
print(fn_tune.timing_results)
print(tune_jax.tabulate(fn_tune))
# Out:
# {0: TimingResult(hyperparams={'steps': 1}, t_mean=1.978333333333333e-06, t_std=1.247219128924741e-09), 1: TimingResult(hyperparams={'steps': 2}, t_mean=2.891666666666667e-06, t_std=2.819377393838738e-08), 2: TimingResult(hyperparams={'steps': 3}, t_mean=3.924333333333333e-06, t_std=9.177266598624108e-09), 3: TimingResult(hyperparams={'steps': 30}, t_mean=2.7376e-05, t_std=1.4142135623730016e-09), 4: TimingResult(hyperparams={'steps': 50}, t_mean=4.4640999999999995e-05, t_std=1.1032074449833296e-07)}
#   id    steps    t_mean (s)    t_std (s)
# ----  -------  ------------  -----------
#    0        1    1.9783e-06   1.2472e-09
#    1        2    2.8917e-06   2.8194e-08
#    2        3    3.9243e-06   9.1773e-09
#    3       30    2.7376e-05   1.4142e-09
#    4       50    4.4641e-05   1.1032e-07

# %% [markdown]
# ### Config

# %%
pprint(tune_jax.CONFIG)
# Out:
# _Config(allow_fallback_timing=False,
#         must_find_at_least_profiler_result_fraction=0.5,
#         profiling_samples=5)

# %%
# how many samples to use for profiling (discards 1 slowest and 1 fastest
# sample) each xprof parsing takes at least 1-5 seconds so 5 might mean 25 s
# profiling even
tune_jax.CONFIG.profiling_samples = 5

# %%
# whether to throw an error if Python fallback profiling is necessary
tune_jax.CONFIG.allow_fallback_timing = False

# %%
# some hyperparam settings might not run correctly under profile / fail to parse from xprof
# what fraction should run before we fall back to Python timing
tune_jax.CONFIG.must_find_at_least_profiler_result_fraction = 0.5

# %% [markdown]
# ### Subsampling

# %%
x = jnp.ones((16, 1024))
W = jnp.ones((1024, 1024))

hyperparams = {"steps": [1, 2, 3, 30, 50]}
fn_tune = tune_jax.tune(fn, hyperparams=hyperparams, sample_num=3)
fn_tune(x, W)
print(fn_tune.timing_results)
print(tune_jax.tabulate(fn_tune))
# Out:
# {0: TimingResult(hyperparams={'steps': 1}, t_mean=1.974333333333333e-06, t_std=1.699673171197584e-09), 1: TimingResult(hyperparams={'steps': 2}, t_mean=2.8996666666666665e-06, t_std=9.92382094871841e-08), 2: TimingResult(hyperparams={'steps': 3}, t_mean=3.694666666666667e-06, t_std=3.3993463423952513e-09)}
#   id    steps    t_mean (s)    t_std (s)
# ----  -------  ------------  -----------
#    0        1    1.9743e-06   1.6997e-09
#    1        2    2.8997e-06   9.9238e-08
#    2        3    3.6947e-06   3.3993e-09

# %% [markdown]
# ### If all hyperparams fail

# %%
@partial(jax.jit, static_argnames=("steps",))
def fn(x, W, steps=20):
  raise ValueError("Refusing to compile")
  for i in range(steps):
    x = (x @ W) / jnp.linalg.norm(x, axis=-1, keepdims=True)
  return x

# %%
# if all hyperparameters fail to compile (a common error) prints
# "No hyperameters compiled successfully"
# and will print ALL errors – a wall of text
tune_jax.tune(fn, hyperparams={"steps": list(range(10))})(x, W)
# Out:
# ERROR:tune_jax:Hyperparameters (0,) failed to compile with message:
# Traceback (most recent call last):
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 109, in _try_call
#     _ = jax.jit(fn).lower(*args_val, **kws_val).compile()
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 325, in jit_lower
#     return jit_trace(jit_func, *args, **kwargs).lower()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 312, in jit_trace
#     p, args_flat = _infer_params(jit_func._fun, jit_func._jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 150, in _fn
#     return fn_to_tune(*args, **dict(kws, **hyperparams))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 314, in _argnames_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 288, in _argnums_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19848/3934216352.py", line 3, in fn
#     raise ValueError("Refusing to compile")
# ValueError: Refusing to compile
#
# ERROR:tune_jax:Hyperparameters (1,) failed to compile with message:
# Traceback (most recent call last):
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 109, in _try_call
#     _ = jax.jit(fn).lower(*args_val, **kws_val).compile()
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 325, in jit_lower
#     return jit_trace(jit_func, *args, **kwargs).lower()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 312, in jit_trace
#     p, args_flat = _infer_params(jit_func._fun, jit_func._jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 150, in _fn
#     return fn_to_tune(*args, **dict(kws, **hyperparams))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 314, in _argnames_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 288, in _argnums_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19848/3934216352.py", line 3, in fn
#     raise ValueError("Refusing to compile")
# ValueError: Refusing to compile
#
# ERROR:tune_jax:Hyperparameters (2,) failed to compile with message:
# Traceback (most recent call last):
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 109, in _try_call
#     _ = jax.jit(fn).lower(*args_val, **kws_val).compile()
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 325, in jit_lower
#     return jit_trace(jit_func, *args, **kwargs).lower()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 312, in jit_trace
#     p, args_flat = _infer_params(jit_func._fun, jit_func._jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 150, in _fn
#     return fn_to_tune(*args, **dict(kws, **hyperparams))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 314, in _argnames_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 288, in _argnums_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19848/3934216352.py", line 3, in fn
#     raise ValueError("Refusing to compile")
# ValueError: Refusing to compile
#
# ERROR:tune_jax:Hyperparameters (3,) failed to compile with message:
# Traceback (most recent call last):
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 109, in _try_call
#     _ = jax.jit(fn).lower(*args_val, **kws_val).compile()
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 325, in jit_lower
#     return jit_trace(jit_func, *args, **kwargs).lower()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 312, in jit_trace
#     p, args_flat = _infer_params(jit_func._fun, jit_func._jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 150, in _fn
#     return fn_to_tune(*args, **dict(kws, **hyperparams))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 314, in _argnames_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 288, in _argnums_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19848/3934216352.py", line 3, in fn
#     raise ValueError("Refusing to compile")
# ValueError: Refusing to compile
#
# ERROR:tune_jax:Hyperparameters (4,) failed to compile with message:
# Traceback (most recent call last):
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 109, in _try_call
#     _ = jax.jit(fn).lower(*args_val, **kws_val).compile()
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 325, in jit_lower
#     return jit_trace(jit_func, *args, **kwargs).lower()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 312, in jit_trace
#     p, args_flat = _infer_params(jit_func._fun, jit_func._jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 150, in _fn
#     return fn_to_tune(*args, **dict(kws, **hyperparams))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 314, in _argnames_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 288, in _argnums_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19848/3934216352.py", line 3, in fn
#     raise ValueError("Refusing to compile")
# ValueError: Refusing to compile
#
# ERROR:tune_jax:Hyperparameters (5,) failed to compile with message:
# Traceback (most recent call last):
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 109, in _try_call
#     _ = jax.jit(fn).lower(*args_val, **kws_val).compile()
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
# ...
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 150, in _fn
#     return fn_to_tune(*args, **dict(kws, **hyperparams))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 314, in _argnames_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 288, in _argnums_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19848/3934216352.py", line 3, in fn
#     raise ValueError("Refusing to compile")
# ValueError: Refusing to compile
#
# ERROR:tune_jax:Hyperparameters (9,) failed to compile with message:
# Traceback (most recent call last):
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 109, in _try_call
#     _ = jax.jit(fn).lower(*args_val, **kws_val).compile()
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 325, in jit_lower
#     return jit_trace(jit_func, *args, **kwargs).lower()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 312, in jit_trace
#     p, args_flat = _infer_params(jit_func._fun, jit_func._jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/tune_jax/tuning.py", line 150, in _fn
#     return fn_to_tune(*args, **dict(kws, **hyperparams))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 270, in cache_miss
#     executable, pgle_profiler, const_args) = _python_pjit_helper(
#                                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 139, in _python_pjit_helper
#     p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 643, in _infer_params
#     return _infer_params_internal(fun, ji, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 667, in _infer_params_internal
#     p, args_flat = _infer_params_impl(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 564, in _infer_params_impl
#     jaxpr, consts, out_avals = _create_pjit_jaxpr(
#                                ^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 472, in memoized_fun
#     ans = call(fun, *args)
#           ^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/pjit.py", line 1351, in _create_pjit_jaxpr
#     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py", line 2350, in trace_to_jaxpr_dynamic
#     ans = fun.call_wrapped(*in_tracers)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 212, in call_wrapped
#     return self.f_transformed(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 73, in flatten_fun
#     ans = f(*py_args, **py_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 314, in _argnames_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/api_util.py", line 288, in _argnums_partial
#     return _fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rdyro_google_com/venv/lib/python3.12/site-packages/jax/_src/linear_util.py", line 397, in _get_result_paths_thunk
#     ans = _fun(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_19848/3934216352.py", line 3, in fn
#     raise ValueError("Refusing to compile")
# ValueError: Refusing to compile
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       1 # if all hyperparameters fail to compile (a common error) prints
#       2 # "No hyperameters compiled successfully"
#       3 # and will print ALL errors – a wall of text
# ----> 4 tune_jax.tune(fn, hyperparams={"steps": list(range(10))})(x, W)
#
# File ~/venv/lib/python3.12/site-packages/tune_jax/tuning.py:576, in tune.<locals>.wrapped_fn(*args, **kws)
#     574 else:
#     575   with jax.core.eval_context():
# --> 576     _, optimal_hyperparameters, results = _get_best_hyperparams(args, kws)
#     577   if maybe_hash is not None:
#     578     wrapped_fn.hyperparams_cache[maybe_hash] = (optimal_hyperparameters, results)
#
# File ~/venv/lib/python3.12/site-packages/tune_jax/tuning.py:514, in tune.<locals>._get_best_hyperparams(args, kws)
#     509   for i, compile_result in compiles.items():
#     510     logger.error(
#     511       f"Hyperparameters {hyperparam_settings[i]} failed to compile with message:"
#     512       f"\n{compile_result.result().error_msg}"
#     513     )
# --> 514   raise ValueError("No hyperparameters compiled successfully")
#     515 logger.debug("Down to %d hyperparameters", len(successful_compiles))
#     516 # cleanup
#
# ValueError: No hyperparameters compiled successfully

# %% [markdown]
# ### Logger config - e.g. , are inputs concrete?

# %%
tune_jax.logger.setLevel("DEBUG")

# %%
tune_jax.tune(lambda x: x)(1)
# Out:
# DEBUG:tune_jax:All arguments are concrete, no need to pick random values.
# DEBUG:tune_jax:All keyword arguments are concrete, no need to pick random values.
# Compiling...: 100%|██████████| 1/1 [00:00<00:00, 46.95it/s]
# Profiling tpu:   0%|          | 0/5 [00:00<?, ?it/s]DEBUG:tune_jax:Saving optimization profile to `/tmp/tuning_profile_2025-09-09_17:42:17_qvtc60m1`
# Profiling tpu: 100%|██████████| 5/5 [00:00<00:00,  6.35it/s]
# DEBUG:tune_jax:
#   id    t_mean (s)    t_std (s)
# ----  ------------  -----------
#    0    5.9400e-07   8.1650e-10
# DEBUG:tune_jax:optimal hyperparams: {}
# 1

# %%
jax.jit(tune_jax.tune(lambda x: x))(1)
# Out:
# DEBUG:tune_jax:Selecting random input arguments.
# DEBUG:tune_jax:All keyword arguments are concrete, no need to pick random values.
# Compiling...: 100%|██████████| 1/1 [00:00<00:00, 46.47it/s]
# Profiling tpu:   0%|          | 0/5 [00:00<?, ?it/s]DEBUG:tune_jax:Saving optimization profile to `/tmp/tuning_profile_2025-09-09_17:42:36_5811u_2_`
# Profiling tpu: 100%|██████████| 5/5 [00:00<00:00,  6.31it/s]
# DEBUG:tune_jax:
#   id    t_mean (s)    t_std (s)
# ----  ------------  -----------
#    0    5.9400e-07   0.0000e+00
# DEBUG:tune_jax:optimal hyperparams: {}
# Array(1, dtype=int32, weak_type=True)
